# %% [markdown]
# # FORK of [ https://www.kaggle.com/stefankahl/birdclef2021-model-training ].

# %% [markdown]
# **Inference notebook** [ https://www.kaggle.com/virajkadam/birdclef-inference ]

# %% [markdown]
# # Model training
#
# In this notebook, we will train our first model and apply this model to a soundscape. We will keep the amount of training samples, species and soundscapes to a minimum to keep the execution time as short as possible. Remember, this is only a sample implementation, feel free to explore your own workflow.
#
# These are the steps that we will cover:
#
#
# * select audio files we want to use for training
# * extract spectrograms from those files and save them in a working directory
# * load selected samples into a large in-memory dataset
# * build a simple beginners CNN
# * train the model
# * apply the model to a selected soundscape and look at the results
#
# # 1. Settings and imports
#
# Let’s begin with imports and a few basic settings.

# %%
import os

import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd
import librosa
import numpy as np
import pickle

from sklearn.utils import shuffle
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow_addons.metrics import F1Score

# %%
# Global vars
RANDOM_SEED = 1337
SAMPLE_RATE = 32000
SIGNAL_LENGTH = 5 # seconds
SPEC_SHAPE = (48, 128) # height x width
FMIN = 500
FMAX = 12500
# MAX_AUDIO_FILES = 10000
EPOCHS=50

# %% [markdown]
# # 2. Data preparation
#
# Taking audio files rated >=4 and having more than 175 samples.

# %%
# Code adapted from: 
# https://www.kaggle.com/frlemarchand/bird-song-classification-using-an-efficientnet
# Make sure to check out the entire notebook.

# Load metadata file
train = pd.read_csv('../input/birdclef-2021/train_metadata.csv',)

# Limit the number of training samples and classes
# First, only use high quality samples
train = train.query('rating>=4')

# Second, assume that birds with the most training samples are also the most common
# A species needs at least 200 recordings with a rating above 4 to be considered common
birds_count = {}
for bird_species, count in zip(train.primary_label.unique(), 
                               train.groupby('primary_label')['primary_label'].count().values):
    birds_count[bird_species] = count
most_represented_birds = [key for key,value in birds_count.items() if value >= 175] 

TRAIN = train.query('primary_label in @most_represented_birds')
LABELS = sorted(TRAIN.primary_label.unique())

# Let's see how many species and samples we have left
print('NUMBER OF SPECIES IN TRAIN DATA:', len(LABELS))
print('NUMBER OF SAMPLES IN TRAIN DATA:', len(TRAIN))
print('LABELS:', most_represented_birds)
# Out:
# NUMBER OF SPECIES IN TRAIN DATA: 40
# NUMBER OF SAMPLES IN TRAIN DATA: 10955
# LABELS: ['amerob', 'azaspi1', 'banana', 'barswa', 'bcnher', 'bewwre', 'blujay', 'bncfly', 'carwre', 'compau', 'comrav', 'comyel', 'cubthr', 'daejun', 'ducfly', 'eursta', 'gbwwre1', 'grasal1', 'grekis', 'grhowl', 'houfin', 'houspa', 'houwre', 'lobgna5', 'mallar3', 'marwre', 'norcar', 'normoc', 'redcro', 'rewbla', 'roahaw', 'rubpep1', 'rucspa1', 'sonspa', 'spotow', 'swathr', 'wbwwre1', 'wesmea', 'whimbr', 'yeofly1']

# %%
# saving labels 
with open('LABELS.pkl','wb') as f:
    pickle.dump(LABELS,f)

# %% [markdown]
# # extracting spectrograms

# %%
# Shuffle the training data and limit the number of audio files to MAX_AUDIO_FILES
TRAIN = shuffle(TRAIN, random_state=RANDOM_SEED)

# Define a function that splits an audio file, 
# extracts spectrograms and saves them in a working directory
def get_spectrograms(filepath, primary_label, output_dir):
    
    # Open the file with librosa (limited to the first 15 seconds)
    sig, rate = librosa.load(filepath, sr=SAMPLE_RATE, offset=None, duration=15)
    
    # Split signal into five second chunks
    sig_splits = []
    for i in range(0, len(sig), int(SIGNAL_LENGTH * SAMPLE_RATE)):
        split = sig[i:i + int(SIGNAL_LENGTH * SAMPLE_RATE)]

        # End of signal?
        if len(split) < int(SIGNAL_LENGTH * SAMPLE_RATE):
            break
        
        sig_splits.append(split)
        
    # Extract mel spectrograms for each audio chunk
    s_cnt = 0
    saved_samples = []
    for chunk in sig_splits:
        
        hop_length = int(SIGNAL_LENGTH * SAMPLE_RATE / (SPEC_SHAPE[1] - 1))
        mel_spec = librosa.feature.melspectrogram(y=chunk, 
                                                  sr=SAMPLE_RATE, 
                                                  n_fft=1024, 
                                                  hop_length=hop_length, 
                                                  n_mels=SPEC_SHAPE[0], 
                                                  fmin=FMIN, 
                                                  fmax=FMAX)
    
        mel_spec = librosa.power_to_db(mel_spec, ref=np.max) 
        
        # Normalize
        mel_spec -= mel_spec.min()
        mel_spec /= mel_spec.max()
        
        # Save as image file
        save_dir = os.path.join(output_dir, primary_label)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        save_path = os.path.join(save_dir, filepath.rsplit(os.sep, 1)[-1].rsplit('.', 1)[0] + 
                                 '_' + str(s_cnt) + '.png')
        im = Image.fromarray(mel_spec * 255.0).convert("L")
        im.save(save_path)
        
        saved_samples.append(save_path)
        s_cnt += 1
        
        
    return saved_samples

print('FINAL NUMBER OF AUDIO FILES IN TRAINING DATA:', len(TRAIN))
# Out:
# FINAL NUMBER OF AUDIO FILES IN TRAINING DATA: 10955

# %%
# Parse audio files and extract training samples
input_dir = '../input/birdclef-2021/train_short_audio/'
output_dir = '../working/melspectrogram_dataset/'
samples = []
with tqdm(total=len(TRAIN)) as pbar:
    for idx, row in TRAIN.iterrows():
        pbar.update(1)
        
        if row.primary_label in most_represented_birds:
            audio_file_path = os.path.join(input_dir, row.primary_label, row.filename)
            samples += get_spectrograms(audio_file_path, row.primary_label, output_dir)
            
TRAIN_SPECS = shuffle(samples, random_state=RANDOM_SEED)
print('SUCCESSFULLY EXTRACTED {} SPECTROGRAMS'.format(len(TRAIN_SPECS)))
# Out:
# 100%|██████████| 10955/10955 [11:44<00:00, 15.54it/s]
# SUCCESSFULLY EXTRACTED 30322 SPECTROGRAMS

# %%
# Plot the first 12 spectrograms of TRAIN_SPECS
plt.figure(figsize=(15, 7))
for i in range(12):
    spec = Image.open(TRAIN_SPECS[i])
    plt.subplot(3, 4, i + 1)
    plt.title(TRAIN_SPECS[i].split(os.sep)[-1])
    plt.imshow(spec, origin='lower')

# %% [markdown]
# Nice! These are good samples. Notice how some of them only contain a fraction of a bird call? That's an issue we won't deal with in this tutorial. We will simply ignore the fact that samples might not contain any bird sounds.
#
# # 4. Load training samples
#
# For now, our spectrograms reside in a working directory. If we want to train a model, we have to load them into memory. Yet, with potentially hundreds of thousands of extracted spectrograms, an in-memory dataset is not a good idea. But for now, loading samples from disk and combining them into a large NumPy array is fine. It’s the easiest way to use these data for training with Keras.

# %%
# Parse all samples and add spectrograms into train data, primary_labels into label data
train_specs, train_labels = [], []
with tqdm(total=len(TRAIN_SPECS)) as pbar:
    for path in TRAIN_SPECS:
        pbar.update(1)

        # Open image
        spec = Image.open(path)

        # Convert to numpy array
        spec = np.array(spec, dtype='float32')
        
        # Normalize between 0.0 and 1.0
        # and exclude samples with nan 
        spec -= spec.min()
        spec /= spec.max()
        if not spec.max() == 1.0 or not spec.min() == 0.0:
            continue

        # Add channel axis to 2D array
        spec = np.expand_dims(spec, -1)

        # Add new dimension for batch size
        spec = np.expand_dims(spec, 0)

        # Add to train data
        if len(train_specs) == 0:
            train_specs = spec
        else:
            train_specs = np.vstack((train_specs, spec))

        # Add to label data
        target = np.zeros((len(LABELS)), dtype='float32')
        bird = path.split(os.sep)[-2]
        target[LABELS.index(bird)] = 1.0
        if len(train_labels) == 0:
            train_labels = target
        else:
            train_labels = np.vstack((train_labels, target))
# Out:
# 100%|██████████| 30322/30322 [1:18:57<00:00,  6.40it/s]

# %% [markdown]
# # 5. Build a simple model

# %%
f1_score=F1Score(num_classes=len(LABELS),average='macro',name='f1_score')

# %% [markdown]
# # Model 1

# %%
# Make sure your experiments are reproducible
tf.random.set_seed(RANDOM_SEED)

# Build a simple model as a sequence of  convolutional blocks.
# Each block has the sequence CONV --> RELU --> BNORM --> MAXPOOL.
# Finally, perform global average pooling and add 2 dense layers.
# The last layer is our classification layer and is softmax activated.
# (Well it's a multi-label task so sigmoid might actually be a better choice)
model = tf.keras.Sequential([
    
    # First conv block
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', 
                           input_shape=(SPEC_SHAPE[0], SPEC_SHAPE[1], 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    # Second conv block
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)), 
    
    # Third conv block
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)), 
    
    # Fourth conv block
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
        
    
    
#     # Global pooling instead of flatten()
    tf.keras.layers.GlobalAveragePooling2D(), 
    
    # Dense block
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(64, activation='relu'),   
#     tf.keras.layers.Dropout(0.5),
    
    # Classification layer
    tf.keras.layers.Dense(len(LABELS), activation='softmax')
])



print('MODEL HAS {} PARAMETERS.'.format(model.count_params()))
# Out:
# MODEL HAS 414760 PARAMETERS.

# %%
# Compile the model and specify optimizer, loss and metric
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.01),
              metrics=['accuracy',f1_score])

# %%
# Add callbacks to reduce the learning rate if needed, early stopping, and checkpoint saving
callbacks = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_f1_score', 
                                                  patience=2, 
                                                  verbose=1, 
                                                  mode='max',
                                                  factor=0.5),
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              verbose=1,
                                              patience=20),
             tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5', 
                                                monitor='val_f1_score',
                                                mode='max',
                                                verbose=1,
                                                save_best_only=True)]

# %%
def plot_history(history):
    his=pd.DataFrame(history.history)
    plt.subplots(1,2,figsize=(16,8))
    
    #loss:
    plt.subplot(1,2,1)
    plt.plot(range(len(his)),his['loss'],color='g',label='training')
    plt.plot(range(len(his)),his['val_loss'],color='r',label='validation')
    plt.legend()
    plt.title('Loss')
    
    #accuracy
    plt.subplot(1,2,2)
    plt.plot(range(len(his)),his['accuracy'],color='g',label='training_acc')
    plt.plot(range(len(his)),his['val_accuracy'],color='r',label='validation_acc')
    
#     #f1_score
#     plt.plot(range(len(his)),his['f1_score'],color='steelblue',label='training_f1')
#     plt.plot(range(len(his)),his['val_f1_score'],color='maroon',label='validation_f1')
    
    plt.legend()
    plt.title('accuracy')
    
    plt.show()

# %% [markdown]
# # TRAINING

# %%
# Let's train the model for a few epochs
his=model.fit(train_specs, 
          train_labels,
          batch_size=32,
          validation_split=0.2,
          callbacks=callbacks,
          epochs=EPOCHS)

plot_history(his)
# Out:
# Epoch 1/50
# 758/758 [==============================] - 117s 152ms/step - loss: 3.2094 - accuracy: 0.1888 - f1_score: 0.1520 - val_loss: 2.2402 - val_accuracy: 0.4144 - val_f1_score: 0.3827
#
# Epoch 00001: val_f1_score improved from -inf to 0.38274, saving model to best_model.h5
# Epoch 2/50
# 758/758 [==============================] - 114s 150ms/step - loss: 2.0011 - accuracy: 0.4791 - f1_score: 0.4573 - val_loss: 1.7805 - val_accuracy: 0.5359 - val_f1_score: 0.5240
#
# Epoch 00002: val_f1_score improved from 0.38274 to 0.52398, saving model to best_model.h5
# Epoch 3/50
# 758/758 [==============================] - 114s 150ms/step - loss: 1.6220 - accuracy: 0.5820 - f1_score: 0.5664 - val_loss: 1.8730 - val_accuracy: 0.5345 - val_f1_score: 0.5401
#
# Epoch 00003: val_f1_score improved from 0.52398 to 0.54012, saving model to best_model.h5
# Epoch 4/50
# 758/758 [==============================] - 114s 151ms/step - loss: 1.4278 - accuracy: 0.6335 - f1_score: 0.6227 - val_loss: 1.4415 - val_accuracy: 0.6321 - val_f1_score: 0.6242
#
# Epoch 00004: val_f1_score improved from 0.54012 to 0.62422, saving model to best_model.h5
# Epoch 5/50
# 758/758 [==============================] - 119s 156ms/step - loss: 1.2846 - accuracy: 0.6778 - f1_score: 0.6664 - val_loss: 1.3685 - val_accuracy: 0.6634 - val_f1_score: 0.6581
#
# Epoch 00005: val_f1_score improved from 0.62422 to 0.65811, saving model to best_model.h5
# Epoch 6/50
# 758/758 [==============================] - 114s 150ms/step - loss: 1.1607 - accuracy: 0.7062 - f1_score: 0.7001 - val_loss: 1.3053 - val_accuracy: 0.6727 - val_f1_score: 0.6624
#
# Epoch 00006: val_f1_score improved from 0.65811 to 0.66239, saving model to best_model.h5
# Epoch 7/50
# 758/758 [==============================] - 112s 148ms/step - loss: 1.0617 - accuracy: 0.7320 - f1_score: 0.7219 - val_loss: 1.4885 - val_accuracy: 0.6209 - val_f1_score: 0.6276
#
# Epoch 00007: val_f1_score did not improve from 0.66239
# Epoch 8/50
# 758/758 [==============================] - 114s 151ms/step - loss: 0.9591 - accuracy: 0.7653 - f1_score: 0.7572 - val_loss: 1.3912 - val_accuracy: 0.6641 - val_f1_score: 0.6574
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_f1_score did not improve from 0.66239
# Epoch 9/50
# 758/758 [==============================] - 115s 151ms/step - loss: 0.7918 - accuracy: 0.8060 - f1_score: 0.7976 - val_loss: 1.2108 - val_accuracy: 0.7101 - val_f1_score: 0.7043
#
# Epoch 00009: val_f1_score improved from 0.66239 to 0.70432, saving model to best_model.h5
# Epoch 10/50
# 758/758 [==============================] - 120s 159ms/step - loss: 0.6823 - accuracy: 0.8392 - f1_score: 0.8329 - val_loss: 1.2627 - val_accuracy: 0.7053 - val_f1_score: 0.7037
#
# Epoch 00010: val_f1_score did not improve from 0.70432
# Epoch 11/50
# 758/758 [==============================] - 127s 168ms/step - loss: 0.6015 - accuracy: 0.8611 - f1_score: 0.8546 - val_loss: 1.2552 - val_accuracy: 0.7038 - val_f1_score: 0.6989
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_f1_score did not improve from 0.70432
# Epoch 12/50
# 758/758 [==============================] - 126s 166ms/step - loss: 0.5139 - accuracy: 0.8919 - f1_score: 0.8844 - val_loss: 1.2397 - val_accuracy: 0.7185 - val_f1_score: 0.7158
#
# Epoch 00012: val_f1_score improved from 0.70432 to 0.71579, saving model to best_model.h5
# Epoch 13/50
# 758/758 [==============================] - 127s 167ms/step - loss: 0.4591 - accuracy: 0.9043 - f1_score: 0.8983 - val_loss: 1.2306 - val_accuracy: 0.7225 - val_f1_score: 0.7160
#
# Epoch 00013: val_f1_score improved from 0.71579 to 0.71603, saving model to best_model.h5
# Epoch 14/50
# 758/758 [==============================] - 121s 160ms/step - loss: 0.4266 - accuracy: 0.9161 - f1_score: 0.9104 - val_loss: 1.3046 - val_accuracy: 0.7177 - val_f1_score: 0.7129
#
# Epoch 00014: val_f1_score did not improve from 0.71603
# Epoch 15/50
# 758/758 [==============================] - 126s 166ms/step - loss: 0.3957 - accuracy: 0.9273 - f1_score: 0.9206 - val_loss: 1.2813 - val_accuracy: 0.7213 - val_f1_score: 0.7160
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00015: val_f1_score improved from 0.71603 to 0.71603, saving model to best_model.h5
# Epoch 16/50
# 758/758 [==============================] - 126s 167ms/step - loss: 0.3570 - accuracy: 0.9397 - f1_score: 0.9353 - val_loss: 1.2849 - val_accuracy: 0.7243 - val_f1_score: 0.7182
#
# Epoch 00016: val_f1_score improved from 0.71603 to 0.71823, saving model to best_model.h5
# Epoch 17/50
# 758/758 [==============================] - 125s 165ms/step - loss: 0.3371 - accuracy: 0.9477 - f1_score: 0.9421 - val_loss: 1.3008 - val_accuracy: 0.7239 - val_f1_score: 0.7192
#
# Epoch 00017: val_f1_score improved from 0.71823 to 0.71922, saving model to best_model.h5
# Epoch 18/50
# 758/758 [==============================] - 127s 167ms/step - loss: 0.3244 - accuracy: 0.9507 - f1_score: 0.9469 - val_loss: 1.3228 - val_accuracy: 0.7180 - val_f1_score: 0.7128
#
# Epoch 00018: val_f1_score did not improve from 0.71922
# Epoch 19/50
# 758/758 [==============================] - 125s 165ms/step - loss: 0.3104 - accuracy: 0.9529 - f1_score: 0.9482 - val_loss: 1.3149 - val_accuracy: 0.7154 - val_f1_score: 0.7107
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00019: val_f1_score did not improve from 0.71922
# Epoch 20/50
# 758/758 [==============================] - 116s 154ms/step - loss: 0.2906 - accuracy: 0.9627 - f1_score: 0.9592 - val_loss: 1.3213 - val_accuracy: 0.7193 - val_f1_score: 0.7135
#
# Epoch 00020: val_f1_score did not improve from 0.71922
# Epoch 21/50
# 758/758 [==============================] - 112s 147ms/step - loss: 0.2854 - accuracy: 0.9641 - f1_score: 0.9600 - val_loss: 1.3175 - val_accuracy: 0.7170 - val_f1_score: 0.7107
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00021: val_f1_score did not improve from 0.71922
# Epoch 22/50
# 758/758 [==============================] - 116s 154ms/step - loss: 0.2791 - accuracy: 0.9629 - f1_score: 0.9587 - val_loss: 1.3309 - val_accuracy: 0.7147 - val_f1_score: 0.7087
#
# Epoch 00022: val_f1_score did not improve from 0.71922
# Epoch 23/50
# 758/758 [==============================] - 117s 155ms/step - loss: 0.2692 - accuracy: 0.9698 - f1_score: 0.9664 - val_loss: 1.3416 - val_accuracy: 0.7173 - val_f1_score: 0.7113
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00023: val_f1_score did not improve from 0.71922
# Epoch 24/50
# 758/758 [==============================] - 117s 154ms/step - loss: 0.2668 - accuracy: 0.9689 - f1_score: 0.9654 - val_loss: 1.3359 - val_accuracy: 0.7178 - val_f1_score: 0.7118
#
# Epoch 00024: val_f1_score did not improve from 0.71922
# Epoch 25/50
# 758/758 [==============================] - 126s 167ms/step - loss: 0.2673 - accuracy: 0.9710 - f1_score: 0.9679 - val_loss: 1.3327 - val_accuracy: 0.7183 - val_f1_score: 0.7125
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00025: val_f1_score did not improve from 0.71922
# Epoch 26/50
# 758/758 [==============================] - 127s 168ms/step - loss: 0.2646 - accuracy: 0.9705 - f1_score: 0.9672 - val_loss: 1.3335 - val_accuracy: 0.7178 - val_f1_score: 0.7121
#
# Epoch 00026: val_f1_score did not improve from 0.71922
# Epoch 27/50
# 758/758 [==============================] - 122s 161ms/step - loss: 0.2623 - accuracy: 0.9735 - f1_score: 0.9697 - val_loss: 1.3339 - val_accuracy: 0.7183 - val_f1_score: 0.7123
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00027: val_f1_score did not improve from 0.71922
# Epoch 28/50
# 758/758 [==============================] - 127s 168ms/step - loss: 0.2624 - accuracy: 0.9701 - f1_score: 0.9664 - val_loss: 1.3328 - val_accuracy: 0.7170 - val_f1_score: 0.7109
#
# Epoch 00028: val_f1_score did not improve from 0.71922
# Epoch 29/50
# 758/758 [==============================] - 127s 168ms/step - loss: 0.2599 - accuracy: 0.9729 - f1_score: 0.9687 - val_loss: 1.3338 - val_accuracy: 0.7172 - val_f1_score: 0.7108
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00029: val_f1_score did not improve from 0.71922
# Epoch 00029: early stopping

# %% [markdown]
# # Model 2

# %%
# Make sure your experiments are reproducible
tf.random.set_seed(RANDOM_SEED)

# Build a simple model as a sequence of  convolutional blocks.
# Each block has the sequence CONV --> RELU --> BNORM --> MAXPOOL.
# Finally, perform global average pooling and add 2 dense layers.
# The last layer is our classification layer and is softmax activated.
# (Well it's a multi-label task so sigmoid might actually be a better choice)
model2 = tf.keras.Sequential([
    
    # First conv block
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', 
                           input_shape=(SPEC_SHAPE[0], SPEC_SHAPE[1], 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    # Second conv block
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)), 
    
    # Third conv block
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)), 
    
    # Fourth conv block
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
        
    
    
#     # Global pooling instead of flatten()
    tf.keras.layers.GlobalAveragePooling2D(), 
    
    # Dense block
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(64, activation='relu'),   
#     tf.keras.layers.Dropout(0.5),
    
    # Classification layer
    tf.keras.layers.Dense(len(LABELS), activation='softmax')
])



print('MODEL HAS {} PARAMETERS.'.format(model2.count_params()))
# Out:
# MODEL HAS 119784 PARAMETERS.

# %%
# Compile the model and specify optimizer, loss and metric
model2.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.01),
              metrics=['accuracy',f1_score])

# Add callbacks to reduce the learning rate if needed, early stopping, and checkpoint saving
callbacks = [tf.keras.callbacks.ReduceLROnPlateau(monitor='val_f1_score',
                                                  mode='max',
                                                  patience=2, 
                                                  verbose=1, 
                                                  factor=0.5),
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              verbose=1,
                                              patience=20),
             tf.keras.callbacks.ModelCheckpoint(filepath='best_model2.h5', 
                                                mode='max',
                                                monitor='val_f1_score',
                                                verbose=0,
                                                save_best_only=True)]

# %%
# Let's train the model for a few epochs
his2=model2.fit(train_specs, 
          train_labels,
          batch_size=32,
          validation_split=0.2,
          callbacks=callbacks,
          verbose=1,
          epochs=EPOCHS)

plot_history(his2)
# Out:
# Epoch 1/50
# 758/758 [==============================] - 99s 129ms/step - loss: 3.2676 - accuracy: 0.1581 - f1_score: 0.3803 - val_loss: 2.4669 - val_accuracy: 0.3537 - val_f1_score: 0.3062
# Epoch 2/50
# 758/758 [==============================] - 100s 132ms/step - loss: 2.2303 - accuracy: 0.4132 - f1_score: 0.3804 - val_loss: 1.9030 - val_accuracy: 0.5028 - val_f1_score: 0.4810
# Epoch 3/50
# 758/758 [==============================] - 100s 131ms/step - loss: 1.8835 - accuracy: 0.5091 - f1_score: 0.4891 - val_loss: 1.7893 - val_accuracy: 0.5417 - val_f1_score: 0.5329
# Epoch 4/50
# 758/758 [==============================] - 94s 124ms/step - loss: 1.7030 - accuracy: 0.5557 - f1_score: 0.5411 - val_loss: 1.5953 - val_accuracy: 0.5932 - val_f1_score: 0.5895
# Epoch 5/50
# 758/758 [==============================] - 100s 132ms/step - loss: 1.5415 - accuracy: 0.6034 - f1_score: 0.5882 - val_loss: 1.5167 - val_accuracy: 0.6194 - val_f1_score: 0.6099
# Epoch 6/50
# 758/758 [==============================] - 99s 131ms/step - loss: 1.4805 - accuracy: 0.6178 - f1_score: 0.6046 - val_loss: 1.5504 - val_accuracy: 0.6072 - val_f1_score: 0.6041
# Epoch 7/50
# 758/758 [==============================] - 93s 123ms/step - loss: 1.3719 - accuracy: 0.6503 - f1_score: 0.6384 - val_loss: 1.4601 - val_accuracy: 0.6319 - val_f1_score: 0.6294
# Epoch 8/50
# 758/758 [==============================] - 99s 130ms/step - loss: 1.2949 - accuracy: 0.6654 - f1_score: 0.6543 - val_loss: 1.3961 - val_accuracy: 0.6520 - val_f1_score: 0.6455
# Epoch 9/50
# 758/758 [==============================] - 97s 128ms/step - loss: 1.2497 - accuracy: 0.6840 - f1_score: 0.6729 - val_loss: 1.5286 - val_accuracy: 0.6214 - val_f1_score: 0.6186
# Epoch 10/50
# 758/758 [==============================] - 90s 118ms/step - loss: 1.1827 - accuracy: 0.7004 - f1_score: 0.6915 - val_loss: 1.3716 - val_accuracy: 0.6530 - val_f1_score: 0.6513
# Epoch 11/50
# 758/758 [==============================] - 92s 121ms/step - loss: 1.1230 - accuracy: 0.7130 - f1_score: 0.7012 - val_loss: 1.3961 - val_accuracy: 0.6539 - val_f1_score: 0.6481
# Epoch 12/50
# 758/758 [==============================] - 90s 118ms/step - loss: 1.0775 - accuracy: 0.7240 - f1_score: 0.7132 - val_loss: 1.4071 - val_accuracy: 0.6504 - val_f1_score: 0.6452
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/50
# 758/758 [==============================] - 99s 131ms/step - loss: 0.9701 - accuracy: 0.7576 - f1_score: 0.7492 - val_loss: 1.2907 - val_accuracy: 0.6891 - val_f1_score: 0.6843
# Epoch 14/50
# 758/758 [==============================] - 92s 122ms/step - loss: 0.8849 - accuracy: 0.7822 - f1_score: 0.7731 - val_loss: 1.3037 - val_accuracy: 0.6863 - val_f1_score: 0.6802
# Epoch 15/50
# 758/758 [==============================] - 94s 124ms/step - loss: 0.8598 - accuracy: 0.7849 - f1_score: 0.7763 - val_loss: 1.3344 - val_accuracy: 0.6786 - val_f1_score: 0.6718
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/50
# 758/758 [==============================] - 97s 128ms/step - loss: 0.7980 - accuracy: 0.8049 - f1_score: 0.7962 - val_loss: 1.2943 - val_accuracy: 0.6949 - val_f1_score: 0.6903
# Epoch 17/50
# 758/758 [==============================] - 92s 121ms/step - loss: 0.7687 - accuracy: 0.8121 - f1_score: 0.8013 - val_loss: 1.3141 - val_accuracy: 0.6981 - val_f1_score: 0.6934
# Epoch 18/50
# 758/758 [==============================] - 97s 128ms/step - loss: 0.7295 - accuracy: 0.8236 - f1_score: 0.8165 - val_loss: 1.3360 - val_accuracy: 0.6936 - val_f1_score: 0.6883
# Epoch 19/50
# 758/758 [==============================] - 94s 124ms/step - loss: 0.7185 - accuracy: 0.8247 - f1_score: 0.8162 - val_loss: 1.3363 - val_accuracy: 0.6957 - val_f1_score: 0.6916
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 20/50
# 758/758 [==============================] - 92s 121ms/step - loss: 0.6798 - accuracy: 0.8378 - f1_score: 0.8292 - val_loss: 1.3169 - val_accuracy: 0.6974 - val_f1_score: 0.6911
# Epoch 21/50
# 758/758 [==============================] - 99s 131ms/step - loss: 0.6613 - accuracy: 0.8440 - f1_score: 0.8361 - val_loss: 1.3392 - val_accuracy: 0.7000 - val_f1_score: 0.6945
# Epoch 22/50
# 758/758 [==============================] - 92s 121ms/step - loss: 0.6350 - accuracy: 0.8536 - f1_score: 0.8444 - val_loss: 1.3481 - val_accuracy: 0.6941 - val_f1_score: 0.6869
# Epoch 23/50
# 758/758 [==============================] - 92s 122ms/step - loss: 0.6341 - accuracy: 0.8517 - f1_score: 0.8431 - val_loss: 1.3484 - val_accuracy: 0.6964 - val_f1_score: 0.6898
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 24/50
# 758/758 [==============================] - 100s 132ms/step - loss: 0.6086 - accuracy: 0.8618 - f1_score: 0.8525 - val_loss: 1.3526 - val_accuracy: 0.6987 - val_f1_score: 0.6937
# Epoch 25/50
# 758/758 [==============================] - 92s 122ms/step - loss: 0.6138 - accuracy: 0.8606 - f1_score: 0.8522 - val_loss: 1.3547 - val_accuracy: 0.7018 - val_f1_score: 0.6960
# Epoch 26/50
# 758/758 [==============================] - 92s 121ms/step - loss: 0.6013 - accuracy: 0.8626 - f1_score: 0.8559 - val_loss: 1.3583 - val_accuracy: 0.6987 - val_f1_score: 0.6936
# Epoch 27/50
# 758/758 [==============================] - 100s 132ms/step - loss: 0.5917 - accuracy: 0.8648 - f1_score: 0.8571 - val_loss: 1.3571 - val_accuracy: 0.6964 - val_f1_score: 0.6902
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 28/50
# 758/758 [==============================] - 92s 122ms/step - loss: 0.5846 - accuracy: 0.8695 - f1_score: 0.8620 - val_loss: 1.3617 - val_accuracy: 0.6994 - val_f1_score: 0.6947
# Epoch 29/50
# 758/758 [==============================] - 92s 121ms/step - loss: 0.5911 - accuracy: 0.8669 - f1_score: 0.8586 - val_loss: 1.3636 - val_accuracy: 0.6994 - val_f1_score: 0.6937
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/50
# 758/758 [==============================] - 101s 133ms/step - loss: 0.5825 - accuracy: 0.8716 - f1_score: 0.8641 - val_loss: 1.3618 - val_accuracy: 0.6966 - val_f1_score: 0.6908
# Epoch 31/50
# 758/758 [==============================] - 94s 124ms/step - loss: 0.5661 - accuracy: 0.8741 - f1_score: 0.8672 - val_loss: 1.3645 - val_accuracy: 0.6964 - val_f1_score: 0.6912
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 32/50
# 758/758 [==============================] - 93s 123ms/step - loss: 0.5780 - accuracy: 0.8703 - f1_score: 0.8638 - val_loss: 1.3666 - val_accuracy: 0.6982 - val_f1_score: 0.6930
# Epoch 33/50
# 758/758 [==============================] - 101s 133ms/step - loss: 0.5820 - accuracy: 0.8699 - f1_score: 0.8623 - val_loss: 1.3665 - val_accuracy: 0.6971 - val_f1_score: 0.6908
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 00033: early stopping

# %% [markdown]
# # 6. Soundscape analysis

# %% [markdown]
# **Soundscape_analysis1**

# %%
# Load the best checkpoint
model = tf.keras.models.load_model('best_model.h5')
model2= tf.keras.models.load_model('best_model2.h5')

# Pick a soundscape
soundscape_path = '../input/birdclef-2021/train_soundscapes/28933_SSW_20170408.ogg'

# Open it with librosa
sig, rate = librosa.load(soundscape_path, sr=SAMPLE_RATE)

# Store results so that we can analyze them later
data = {'row_id': [], 'prediction': [], 'score': []}

# Split signal into 5-second chunks
# Just like we did before (well, this could actually be a seperate function)
sig_splits = []
for i in range(0, len(sig), int(SIGNAL_LENGTH * SAMPLE_RATE)):
    split = sig[i:i + int(SIGNAL_LENGTH * SAMPLE_RATE)]

    # End of signal?
    if len(split) < int(SIGNAL_LENGTH * SAMPLE_RATE):
        break

    sig_splits.append(split)
    
# Get the spectrograms and run inference on each of them
# This should be the exact same process as we used to
# generate training samples!
seconds, scnt = 0, 0
for chunk in sig_splits:
    
    # Keep track of the end time of each chunk
    seconds += 5
        
    # Get the spectrogram
    hop_length = int(SIGNAL_LENGTH * SAMPLE_RATE / (SPEC_SHAPE[1] - 1))
    mel_spec = librosa.feature.melspectrogram(y=chunk, 
                                              sr=SAMPLE_RATE, 
                                              n_fft=1024, 
                                              hop_length=hop_length, 
                                              n_mels=SPEC_SHAPE[0], 
                                              fmin=FMIN, 
                                              fmax=FMAX)

    mel_spec = librosa.power_to_db(mel_spec, ref=np.max) 

    # Normalize to match the value range we used during training.
    # That's something you should always double check!
    mel_spec -= mel_spec.min()
    mel_spec /= mel_spec.max()
    
    # Add channel axis to 2D array
    mel_spec = np.expand_dims(mel_spec, -1)

    # Add new dimension for batch size
    mel_spec = np.expand_dims(mel_spec, 0)
    
    # Predict
    p = model.predict(mel_spec)[0] + model2.predict(mel_spec)[0] 
    
    
    # Get highest scoring species
    idx = p.argmax()
    species = LABELS[idx]
    score = p[idx]
    
    # Prepare submission entry
    data['row_id'].append(soundscape_path.split(os.sep)[-1].rsplit('_', 1)[0] + 
                          '_' + str(seconds))    
    
    # Decide if it's a "nocall" or a species by applying a threshold
    if score > 0.4:
        data['prediction'].append(species)
        scnt += 1
    else:
        data['prediction'].append('nocall')
        
    # Add the confidence score as well
    data['score'].append(score)
        
print('SOUNSCAPE ANALYSIS DONE. FOUND {} BIRDS.'.format(scnt))
# Out:
# SOUNSCAPE ANALYSIS DONE. FOUND 89 BIRDS.

# %%
# Make a new data frame
results = pd.DataFrame(data, columns = ['row_id', 'prediction', 'score'])

# Merge with ground truth so we can inspect
gt = pd.read_csv('../input/birdclef-2021/train_soundscape_labels.csv',)
results = pd.merge(gt, results, on='row_id')

# Let's look at the first 50 entries
results.head(50)
# Out:
#            row_id site  audio_id  seconds                 birds prediction  \
# 0     28933_SSW_5  SSW     28933        5                sonspa     grhowl
# 1    28933_SSW_10  SSW     28933       10                rewbla     grhowl
# 2    28933_SSW_15  SSW     28933       15                sonspa    gbwwre1
# 3    28933_SSW_20  SSW     28933       20                sonspa     grhowl
# 4    28933_SSW_25  SSW     28933       25                sonspa     grhowl
# 5    28933_SSW_30  SSW     28933       30                sonspa     grhowl
# 6    28933_SSW_35  SSW     28933       35                sonspa     grhowl
# 7    28933_SSW_40  SSW     28933       40                sonspa     nocall
# 8    28933_SSW_45  SSW     28933       45                sonspa     grhowl
# 9    28933_SSW_50  SSW     28933       50                sonspa     grhowl
# 10   28933_SSW_55  SSW     28933       55                sonspa     nocall
# 11   28933_SSW_60  SSW     28933       60                sonspa     redcro
# 12   28933_SSW_65  SSW     28933       65                sonspa     grhowl
# 13   28933_SSW_70  SSW     28933       70                sonspa     redcro
# 14   28933_SSW_75  SSW     28933       75                sonspa     houfin
# 15   28933_SSW_80  SSW     28933       80                sonspa     houwre
# 16   28933_SSW_85  SSW     28933       85                sonspa     redcro
# 17   28933_SSW_90  SSW     28933       90                sonspa     sonspa
# 18   28933_SSW_95  SSW     28933       95                sonspa     redcro
# 19  28933_SSW_100  SSW     28933      100         rewbla sonspa     redcro
# 20  28933_SSW_105  SSW     28933      105                sonspa     redcro
# 21  28933_SSW_110  SSW     28933      110                sonspa     redcro
# 22  28933_SSW_115  SSW     28933      115                sonspa     redcro
# 23  28933_SSW_120  SSW     28933      120                sonspa     redcro
# 24  28933_SSW_125  SSW     28933      125                sonspa     sonspa
# 25  28933_SSW_130  SSW     28933      130                sonspa     barswa
# 26  28933_SSW_135  SSW     28933      135                sonspa     redcro
# 27  28933_SSW_140  SSW     28933      140                sonspa     sonspa
# 28  28933_SSW_145  SSW     28933      145         norcar sonspa     rewbla
# 29  28933_SSW_150  SSW     28933      150         norcar sonspa     redcro
# 30  28933_SSW_155  SSW     28933      155  gockin norcar sonspa     houfin
# 31  28933_SSW_160  SSW     28933      160         norcar sonspa     nocall
# 32  28933_SSW_165  SSW     28933      165                sonspa     sonspa
# 33  28933_SSW_170  SSW     28933      170                sonspa     redcro
# 34  28933_SSW_175  SSW     28933      175                sonspa     redcro
# 35  28933_SSW_180  SSW     28933      180                sonspa     nocall
# 36  28933_SSW_185  SSW     28933      185                sonspa     redcro
# 37  28933_SSW_190  SSW     28933      190                sonspa     sonspa
# 38  28933_SSW_195  SSW     28933      195                sonspa     eursta
# 39  28933_SSW_200  SSW     28933      200                sonspa     sonspa
# 40  28933_SSW_205  SSW     28933      205                sonspa     eursta
# 41  28933_SSW_210  SSW     28933      210                sonspa     sonspa
# 42  28933_SSW_215  SSW     28933      215         norcar sonspa     sonspa
# 43  28933_SSW_220  SSW     28933      220         norcar sonspa     eursta
# 44  28933_SSW_225  SSW     28933      225  norcar rewbla sonspa     redcro
# 45  28933_SSW_230  SSW     28933      230                norcar     nocall
# 46  28933_SSW_235  SSW     28933      235         norcar rewbla     eursta
# 47  28933_SSW_240  SSW     28933      240                gockin     grhowl
# 48  28933_SSW_245  SSW     28933      245                nocall     eursta
# 49  28933_SSW_250  SSW     28933      250         amegfi gockin     eursta
#
#        score
# 0   1.330246
# 1   1.790378
# 2   0.468145
# 3   1.536966
# 4   0.775450
# 5   1.159670
# 6   1.357176
# 7   0.394570
# 8   1.396880
# 9   1.010622
# 10  0.341190
# 11  0.441091
# 12  1.136930
# 13  0.986027
# 14  0.467480
# 15  0.547578
# 16  1.395691
# 17  0.870637
# 18  0.937306
# 19  0.957643
# 20  1.056239
# 21  0.418283
# 22  0.766068
# 23  1.396171
# 24  0.595044
# 25  0.445814
# 26  1.120795
# 27  0.773425
# 28  0.513965
# 29  0.685556
# 30  0.600918
# 31  0.392491
# 32  0.801304
# 33  1.149482
# 34  0.983435
# 35  0.313016
# 36  1.040631
# 37  0.887516
# 38  0.496079
# 39  1.218802
# 40  0.528757
# 41  1.558053
# 42  0.530200
# 43  0.436460
# 44  0.505530
# 45  0.204218
# 46  0.921161
# 47  0.531694
# 48  0.822041
# 49  0.613949

# %% [markdown]
# **Soundscape_analysis2_2**

# %%
# Pick a soundscape
soundscape_path = '../input/birdclef-2021/train_soundscapes/7843_SSW_20170325.ogg'

# Open it with librosa
sig, rate = librosa.load(soundscape_path, sr=SAMPLE_RATE)

# Store results so that we can analyze them later
data = {'row_id': [], 'prediction': [], 'score': []}

# Split signal into 5-second chunks
# Just like we did before (well, this could actually be a seperate function)
sig_splits = []
for i in range(0, len(sig), int(SIGNAL_LENGTH * SAMPLE_RATE)):
    split = sig[i:i + int(SIGNAL_LENGTH * SAMPLE_RATE)]

    # End of signal?
    if len(split) < int(SIGNAL_LENGTH * SAMPLE_RATE):
        break

    sig_splits.append(split)
    
# Get the spectrograms and run inference on each of them
# This should be the exact same process as we used to
# generate training samples!
seconds, scnt = 0, 0
for chunk in sig_splits:
    
    # Keep track of the end time of each chunk
    seconds += 5
        
    # Get the spectrogram
    hop_length = int(SIGNAL_LENGTH * SAMPLE_RATE / (SPEC_SHAPE[1] - 1))
    mel_spec = librosa.feature.melspectrogram(y=chunk, 
                                              sr=SAMPLE_RATE, 
                                              n_fft=1024, 
                                              hop_length=hop_length, 
                                              n_mels=SPEC_SHAPE[0], 
                                              fmin=FMIN, 
                                              fmax=FMAX)

    mel_spec = librosa.power_to_db(mel_spec, ref=np.max) 

    # Normalize to match the value range we used during training.
    # That's something you should always double check!
    mel_spec -= mel_spec.min()
    mel_spec /= mel_spec.max()
    
    # Add channel axis to 2D array
    mel_spec = np.expand_dims(mel_spec, -1)

    # Add new dimension for batch size
    mel_spec = np.expand_dims(mel_spec, 0)
    
    # Predict
    p = 0.5*model.predict(mel_spec)[0] + 0.5*model2.predict(mel_spec)[0]
    
    
    # Get highest scoring species
    idx = p.argmax()
    species = LABELS[idx]
    score = p[idx]
    
    # Prepare submission entry
    data['row_id'].append(soundscape_path.split(os.sep)[-1].rsplit('_', 1)[0] + 
                          '_' + str(seconds))    
    
    # Decide if it's a "nocall" or a species by applying a threshold
    if score > 0.45:
        data['prediction'].append(species)
        scnt += 1
    else:
        data['prediction'].append('nocall')
        
    # Add the confidence score as well
    data['score'].append(score)
        
print('SOUNSCAPE ANALYSIS DONE. FOUND {} BIRDS.'.format(scnt))
# Out:
# SOUNSCAPE ANALYSIS DONE. FOUND 2 BIRDS.

# %%
# Make a new data frame
results = pd.DataFrame(data, columns = ['row_id', 'prediction', 'score'])

# Merge with ground truth so we can inspect
gt = pd.read_csv('../input/birdclef-2021/train_soundscape_labels.csv',)
results = pd.merge(gt, results, on='row_id')

# Let's look at the first 50 entries
results.head(50)
# Out:
#           row_id site  audio_id  seconds   birds prediction     score
# 0     7843_SSW_5  SSW      7843        5  nocall     nocall  0.079551
# 1    7843_SSW_10  SSW      7843       10  nocall     nocall  0.409659
# 2    7843_SSW_15  SSW      7843       15  nocall     nocall  0.121734
# 3    7843_SSW_20  SSW      7843       20  nocall     nocall  0.104086
# 4    7843_SSW_25  SSW      7843       25  nocall     nocall  0.418659
# 5    7843_SSW_30  SSW      7843       30  nocall     nocall  0.222621
# 6    7843_SSW_35  SSW      7843       35  nocall     nocall  0.120765
# 7    7843_SSW_40  SSW      7843       40  nocall     nocall  0.079258
# 8    7843_SSW_45  SSW      7843       45  nocall     nocall  0.145408
# 9    7843_SSW_50  SSW      7843       50  nocall     nocall  0.204980
# 10   7843_SSW_55  SSW      7843       55  nocall     nocall  0.099922
# 11   7843_SSW_60  SSW      7843       60  nocall     nocall  0.128052
# 12   7843_SSW_65  SSW      7843       65  nocall     nocall  0.166486
# 13   7843_SSW_70  SSW      7843       70  nocall     nocall  0.117700
# 14   7843_SSW_75  SSW      7843       75  nocall     nocall  0.089347
# 15   7843_SSW_80  SSW      7843       80  nocall     nocall  0.090284
# 16   7843_SSW_85  SSW      7843       85  nocall     nocall  0.186825
# 17   7843_SSW_90  SSW      7843       90  nocall     nocall  0.147237
# 18   7843_SSW_95  SSW      7843       95  nocall     nocall  0.227294
# 19  7843_SSW_100  SSW      7843      100  nocall     nocall  0.097198
# 20  7843_SSW_105  SSW      7843      105  nocall     nocall  0.196428
# 21  7843_SSW_110  SSW      7843      110  nocall     nocall  0.103852
# 22  7843_SSW_115  SSW      7843      115  nocall     nocall  0.171647
# 23  7843_SSW_120  SSW      7843      120  nocall     nocall  0.174538
# 24  7843_SSW_125  SSW      7843      125  nocall     nocall  0.145029
# 25  7843_SSW_130  SSW      7843      130  nocall     nocall  0.211901
# 26  7843_SSW_135  SSW      7843      135  nocall     nocall  0.113931
# 27  7843_SSW_140  SSW      7843      140  nocall     nocall  0.200700
# 28  7843_SSW_145  SSW      7843      145  nocall     nocall  0.193164
# 29  7843_SSW_150  SSW      7843      150  nocall     nocall  0.203697
# 30  7843_SSW_155  SSW      7843      155  nocall     nocall  0.115281
# 31  7843_SSW_160  SSW      7843      160  nocall     nocall  0.325112
# 32  7843_SSW_165  SSW      7843      165  nocall     daejun  0.695023
# 33  7843_SSW_170  SSW      7843      170  nocall     nocall  0.132934
# 34  7843_SSW_175  SSW      7843      175  nocall     nocall  0.322020
# 35  7843_SSW_180  SSW      7843      180  nocall     nocall  0.173263
# 36  7843_SSW_185  SSW      7843      185  nocall     nocall  0.119599
# 37  7843_SSW_190  SSW      7843      190  nocall     nocall  0.150549
# 38  7843_SSW_195  SSW      7843      195  nocall     nocall  0.104610
# 39  7843_SSW_200  SSW      7843      200  nocall     nocall  0.105457
# 40  7843_SSW_205  SSW      7843      205  nocall     nocall  0.231296
# 41  7843_SSW_210  SSW      7843      210  nocall     nocall  0.154234
# 42  7843_SSW_215  SSW      7843      215  nocall     nocall  0.139870
# 43  7843_SSW_220  SSW      7843      220  nocall     nocall  0.103671
# 44  7843_SSW_225  SSW      7843      225  nocall     nocall  0.105436
# 45  7843_SSW_230  SSW      7843      230  nocall     nocall  0.186320
# 46  7843_SSW_235  SSW      7843      235  nocall     nocall  0.143059
# 47  7843_SSW_240  SSW      7843      240  nocall     nocall  0.441985
# 48  7843_SSW_245  SSW      7843      245  nocall     nocall  0.181933
# 49  7843_SSW_250  SSW      7843      250  nocall     nocall  0.077755

# %% [markdown]
# **Soundscape_analysis_3**

# %%
# Pick a soundscape
soundscape_path = '../input/birdclef-2021/train_soundscapes/26709_SSW_20170701.ogg'

# Open it with librosa
sig, rate = librosa.load(soundscape_path, sr=SAMPLE_RATE)

# Store results so that we can analyze them later
data = {'row_id': [], 'prediction': [], 'score': []}

# Split signal into 5-second chunks
# Just like we did before (well, this could actually be a seperate function)
sig_splits = []
for i in range(0, len(sig), int(SIGNAL_LENGTH * SAMPLE_RATE)):
    split = sig[i:i + int(SIGNAL_LENGTH * SAMPLE_RATE)]

    # End of signal?
    if len(split) < int(SIGNAL_LENGTH * SAMPLE_RATE):
        break

    sig_splits.append(split)
    
# Get the spectrograms and run inference on each of them
# This should be the exact same process as we used to
# generate training samples!
seconds, scnt = 0, 0
for chunk in sig_splits:
    
    # Keep track of the end time of each chunk
    seconds += 5
        
    # Get the spectrogram
    hop_length = int(SIGNAL_LENGTH * SAMPLE_RATE / (SPEC_SHAPE[1] - 1))
    mel_spec = librosa.feature.melspectrogram(y=chunk, 
                                              sr=SAMPLE_RATE, 
                                              n_fft=1024, 
                                              hop_length=hop_length, 
                                              n_mels=SPEC_SHAPE[0], 
                                              fmin=FMIN, 
                                              fmax=FMAX)

    mel_spec = librosa.power_to_db(mel_spec, ref=np.max) 

    # Normalize to match the value range we used during training.
    # That's something you should always double check!
    mel_spec -= mel_spec.min()
    mel_spec /= mel_spec.max()
    
    # Add channel axis to 2D array
    mel_spec = np.expand_dims(mel_spec, -1)

    # Add new dimension for batch size
    mel_spec = np.expand_dims(mel_spec, 0)
    
    # Predict
    p = 0.5*model.predict(mel_spec)[0] + 0.5*model2.predict(mel_spec)[0]
    
    
    # Get highest scoring species
    idx = p.argmax()
    species = LABELS[idx]
    score = p[idx]
    
    # Prepare submission entry
    data['row_id'].append(soundscape_path.split(os.sep)[-1].rsplit('_', 1)[0] + 
                          '_' + str(seconds))    
    
    # Decide if it's a "nocall" or a species by applying a threshold
    if score > 0.3:
        data['prediction'].append(species)
        scnt += 1
    else:
        data['prediction'].append('nocall')
        
    # Add the confidence score as well
    data['score'].append(score)
        
print('SOUNSCAPE ANALYSIS DONE. FOUND {} BIRDS.'.format(scnt))
# Out:
# SOUNSCAPE ANALYSIS DONE. FOUND 39 BIRDS.

# %%
# Make a new data frame
results = pd.DataFrame(data, columns = ['row_id', 'prediction', 'score'])

# Merge with ground truth so we can inspect
gt = pd.read_csv('../input/birdclef-2021/train_soundscape_labels.csv',)
results = pd.merge(gt, results, on='row_id')

# Let's look at the first 50 entries
results.head(50)
# Out:
#            row_id site  audio_id  seconds   birds prediction     score
# 0     26709_SSW_5  SSW     26709        5  amegfi     nocall  0.104044
# 1    26709_SSW_10  SSW     26709       10  nocall     nocall  0.162222
# 2    26709_SSW_15  SSW     26709       15  nocall    mallar3  0.430346
# 3    26709_SSW_20  SSW     26709       20  nocall     nocall  0.256517
# 4    26709_SSW_25  SSW     26709       25  nocall     nocall  0.268255
# 5    26709_SSW_30  SSW     26709       30  nocall     grhowl  0.389380
# 6    26709_SSW_35  SSW     26709       35  nocall     nocall  0.267538
# 7    26709_SSW_40  SSW     26709       40  nocall     nocall  0.216172
# 8    26709_SSW_45  SSW     26709       45  nocall     grhowl  0.527358
# 9    26709_SSW_50  SSW     26709       50  nocall     grhowl  0.345351
# 10   26709_SSW_55  SSW     26709       55  nocall     nocall  0.167422
# 11   26709_SSW_60  SSW     26709       60  nocall     nocall  0.254144
# 12   26709_SSW_65  SSW     26709       65  nocall     nocall  0.255390
# 13   26709_SSW_70  SSW     26709       70  nocall     nocall  0.147679
# 14   26709_SSW_75  SSW     26709       75  nocall     nocall  0.178802
# 15   26709_SSW_80  SSW     26709       80  nocall     nocall  0.271133
# 16   26709_SSW_85  SSW     26709       85  nocall     nocall  0.299437
# 17   26709_SSW_90  SSW     26709       90  comyel     nocall  0.242405
# 18   26709_SSW_95  SSW     26709       95  nocall     nocall  0.219395
# 19  26709_SSW_100  SSW     26709      100  nocall     nocall  0.110238
# 20  26709_SSW_105  SSW     26709      105  comyel     nocall  0.135176
# 21  26709_SSW_110  SSW     26709      110  comyel     nocall  0.148026
# 22  26709_SSW_115  SSW     26709      115  nocall     nocall  0.108353
# 23  26709_SSW_120  SSW     26709      120  nocall     grhowl  0.410773
# 24  26709_SSW_125  SSW     26709      125  nocall     grhowl  0.647544
# 25  26709_SSW_130  SSW     26709      130  nocall     nocall  0.201133
# 26  26709_SSW_135  SSW     26709      135  nocall     nocall  0.103257
# 27  26709_SSW_140  SSW     26709      140  nocall     grhowl  0.496020
# 28  26709_SSW_145  SSW     26709      145  nocall     grhowl  0.711368
# 29  26709_SSW_150  SSW     26709      150  nocall     grhowl  0.532865
# 30  26709_SSW_155  SSW     26709      155  nocall     grhowl  0.370686
# 31  26709_SSW_160  SSW     26709      160  nocall     comrav  0.428465
# 32  26709_SSW_165  SSW     26709      165  nocall     nocall  0.149019
# 33  26709_SSW_170  SSW     26709      170  nocall     nocall  0.220250
# 34  26709_SSW_175  SSW     26709      175  nocall     nocall  0.119434
# 35  26709_SSW_180  SSW     26709      180  nocall     nocall  0.159943
# 36  26709_SSW_185  SSW     26709      185  comyel     grhowl  0.303182
# 37  26709_SSW_190  SSW     26709      190  nocall     grhowl  0.351369
# 38  26709_SSW_195  SSW     26709      195  nocall     nocall  0.125365
# 39  26709_SSW_200  SSW     26709      200  nocall     nocall  0.071554
# 40  26709_SSW_205  SSW     26709      205  nocall     nocall  0.197329
# 41  26709_SSW_210  SSW     26709      210  nocall     nocall  0.125690
# 42  26709_SSW_215  SSW     26709      215  nocall     nocall  0.106638
# 43  26709_SSW_220  SSW     26709      220  nocall     nocall  0.173662
# 44  26709_SSW_225  SSW     26709      225  nocall     redcro  0.376397
# 45  26709_SSW_230  SSW     26709      230  nocall    mallar3  0.569204
# 46  26709_SSW_235  SSW     26709      235  comyel     sonspa  0.311481
# 47  26709_SSW_240  SSW     26709      240  sonspa     sonspa  0.561569
# 48  26709_SSW_245  SSW     26709      245  comyel     nocall  0.087627
# 49  26709_SSW_250  SSW     26709      250  sonspa     nocall  0.142929

# %% [markdown]
# # Prediction
# **Inference notebook** [ https://www.kaggle.com/virajkadam/birdclef-inference ]
